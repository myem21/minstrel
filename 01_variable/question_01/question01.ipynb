# %%
name = '정종현'

age = 56

print(name, age)
# Out:
# 정종현 56

# %%
print(name, age, end='\nn') 
print(name, age, sep='n') 
print( age)
# Out:
# 정종현 56
# n정종현n56
# 56

# %% [markdown]
# print(name)
# print( age)
